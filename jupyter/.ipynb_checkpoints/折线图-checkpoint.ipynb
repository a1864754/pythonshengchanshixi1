# %% [markdown]
# # 1Pandas疫情探索性分析

# %% [markdown]
# ## 1.1 使用apply函数，探索1960-2014美国犯罪数据

# %% [markdown]
# ### 1.1.1将数据命名为crime

# %%
import pandas as pd
import numpy as np
crime = pd.read_csv('../data/US_Crime_Rates_1960_2014.csv')
crime.head(2)
# Out:
#    Unnamed: 0  Year  Population    Total  Violent  Property  Murder  \
# 0           0  1960   179323175  3384200   288460   3095700    9110
# 1           1  1961   182992000  3488000   289390   3198600    8740
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
#
#    Vehicle_Theft
# 0         328200
# 1         336000

# %% [markdown]
# ### 1.1.2 查看每一列的数据类型

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
# Unnamed: 0            55 non-null int64
# Year                  55 non-null int64
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: int64(13)
# memory usage: 5.7 KB

# %% [markdown]
# ### 1.1.3 将Year的数据类型转化为datetime格式

# %%
crime["Year"] = pd.to_datetime(crime['Year'],format='%Y')
crime.head(3)
# Out:
#    Unnamed: 0       Year  Population    Total  Violent  Property  Murder  \
# 0           0 1960-01-01   179323175  3384200   288460   3095700    9110
# 1           1 1961-01-01   182992000  3488000   289390   3198600    8740
# 2           2 1962-01-01   185771000  3752200   301510   3450700    8530
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800

# %% [markdown]
# ### 1.1.4 将Year设置为索引列

# %%
# crime.set_index('Year',inplace=True)
crime.head(5)
# Out:
#    Unnamed: 0       Year  Population    Total  Violent  Property  Murder  \
# 0           0 1960-01-01   179323175  3384200   288460   3095700    9110
# 1           1 1961-01-01   182992000  3488000   289390   3198600    8740
# 2           2 1962-01-01   185771000  3752200   301510   3450700    8530
# 3           3 1963-01-01   188483000  4109500   316970   3792500    8640
# 4           4 1964-01-01   191141000  4564600   364220   4200400    9360
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
# 3          17650   116470              174210   1086400        2297800
# 4          21420   130390              203050   1213200        2514400
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800
# 3         408300
# 4         472800

# %% [markdown]
# ### 1.1.5 删除Total列

# %%
# crime.drop(labels='Unnamed: 0',axis=1,inplace=True)
# crime.drop(labels='Total',axis=1,inplace=True)
crime.head(5)
# Out:
#    Unnamed: 0       Year  Population    Total  Violent  Property  Murder  \
# 0           0 1960-01-01   179323175  3384200   288460   3095700    9110
# 1           1 1961-01-01   182992000  3488000   289390   3198600    8740
# 2           2 1962-01-01   185771000  3752200   301510   3450700    8530
# 3           3 1963-01-01   188483000  4109500   316970   3792500    8640
# 4           4 1964-01-01   191141000  4564600   364220   4200400    9360
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
# 3          17650   116470              174210   1086400        2297800
# 4          21420   130390              203050   1213200        2514400
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800
# 3         408300
# 4         472800

# %% [markdown]
# ### 1.1.6 按照Year（每十年）对数据进行分组求和

# %%
# W 星期
# M 月
# Q 季度
# QA 季度开始的第一天
# A 年
# AS 按年聚合的第一天
#crime.resample("10AS").sum()
crime.head(3)
# Out:
#    Unnamed: 0       Year  Population    Total  Violent  Property  Murder  \
# 0           0 1960-01-01   179323175  3384200   288460   3095700    9110
# 1           1 1961-01-01   182992000  3488000   289390   3198600    8740
# 2           2 1962-01-01   185771000  3752200   301510   3450700    8530
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800

# %% [markdown]
# ### 1.1.7 什么时候美国历史上生存最危险的年代

# %% [markdown]
# ### 1.2 股价数据

# %%
apple =pd.read_csv("../data/appl_1980_2014.csv")
apple.head(5)
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
# Date         8465 non-null object
# Open         8465 non-null float64
# High         8465 non-null float64
# Low          8465 non-null float64
# Close        8465 non-null float64
# Volume       8465 non-null int64
# Adj Close    8465 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.0+ KB

# %%
apple["Date"] = pd.to_datetime(apple["Date"])
apple.head(3)
# Out:
#         Date   Open   High    Low  Close    Volume  Adj Close
# 0 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03

# %%
apple.set_index("Date",inplace=True)
apple.head(3)
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03

# %%
apple.index.shape == apple.index.unique().shape # 判断是否有重复
# Out:
# True

# %%
apple = apple.sort_index() # 根据Date排序
apple.head(5)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
# 找到每月最后一个交易日
mid = apple.groupby(by=[apple.index.year,apple.index.month]).agg(lambda x :x.index.max())
mid.iloc[:,0].head()
# Out:
# Date  Date
# 1980  12     1980-12-31
# 1981  1      1981-01-30
#       2      1981-02-27
#       3      1981-03-31
#       4      1981-04-30
# Name: Open, dtype: datetime64[ns]

# %%
# 数据中最早的日期和最晚的日期相差多少天
(apple.index.max()-apple.index.min()).days
# Out:
# 12261

# %%
# 数据中一共有多少月
mid.shape[0]
# Out:
# 404

# %%
# 按照时间序列做可视化
import matplotlib.pyplot as plt
apple_open = apple['Adj Close'].plot(color='red',title = 'Apple Stock')
fig = apple_open.get_figure()
fig.set_size_inches(16,8)
plt.grid()
plt.ylim(-5,100)
plt.show()

# %% [markdown]
# ## 全国历史数据分析

# %%
alltime_china = pd.read_csv('../covid_data/alltime_China_2020_04_27.csv')
# alltime_china

# %%
alltime_china.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 15 columns):
# date                  98 non-null object
# lastUpdateTime        0 non-null float64
# total_confirm         98 non-null int64
# total_suspect         98 non-null int64
# total_heal            98 non-null int64
# total_dead            98 non-null int64
# total_severe          98 non-null int64
# total_input           98 non-null int64
# today_confirm         98 non-null int64
# today_suspect         98 non-null int64
# today_heal            98 non-null int64
# today_dead            98 non-null int64
# today_severe          98 non-null int64
# today_storeConfirm    0 non-null float64
# today_input           54 non-null float64
# dtypes: float64(3), int64(11), object(1)
# memory usage: 11.6+ KB

# %%
name_dict = {'date':"日期",'id':"编号", 'name':'名称', 'lastUpdateTime':'更新时间', 'total_confirm':'累计确诊', 'total_suspect':'累计疑似',
       'total_heal':'累计治愈', 'total_dead':'累计死亡', 'total_severe':'累计重症', 'total_input':'累计输入',
       'total_newConfirm':'累计新增确诊', 'total_newDead':'累计新增死亡', 'total_newHeal':'累计新增治愈', 'today_confirm':'当日新增确诊',
       'today_suspect':'当日新增疑似', 'today_heal':'当日新增治愈', 'today_dead':'当日新增死亡', 'today_severe':'当日新增疑似',
       'today_storeConfirm':'当日现存确诊', 'today_input':'当日新增输入'}

# %%
alltime_china.rename(columns=name_dict,inplace=True)

# %%
# alltime_china.head(5)

# %%
# 计算当日现存确诊
alltime_china["当日现存确诊"] = alltime_china['累计确诊'] - alltime_china['累计死亡']-alltime_china['累计治愈']
# alltime_china.head(5)

# %%
# 删除更新时间、累计输入、当日新增输入
# 多列删除
alltime_china.drop(['更新时间','累计输入','当日新增输入'],axis=1,inplace=True)
# alltime_china.drop(['当日新增疑似'],axis=1,inplace=True)

# %%
alltime_china.head()
# Out:
#            日期  累计确诊  累计疑似  累计治愈  累计死亡  累计重症  当日新增确诊  当日新增疑似  当日新增治愈  当日新增死亡  \
# 0  2020-01-20   291    54    25     6     0     291      27      25       6
# 1  2020-01-21   440    37    25     9   102     149      26     -25       3
# 2  2020-01-22   571   393    28    17    95     131     257      28       8
# 3  2020-01-23   830  1072    34    25   177     259     680       6       8
# 4  2020-01-24  1287  1965    38    41   237     444    1118       4      16
#
#    当日新增疑似  当日现存确诊
# 0       0     260
# 1       0     406
# 2       0     526
# 3       0     771
# 4       0    1208

# %%
# 单列删除
#alltime_china.drop(['当日新增疑似'],axis=1,inplace=True)
#alltime_china.drop(labels='更新时间',axis=1,inplace=True)

# %%
#将日期设置为索引
alltime_china.set_index('日期',inplace=True)

# %%
alltime_china.index
# Out:
# Index(['2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#        '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#        '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03',
#        '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#        '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#        '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#        '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22', '2020-02-23',
#        '2020-02-24', '2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28',
#        '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#        '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14',
#        '2020-03-15', '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19',
#        '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24',
#        '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29',
#        '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03',
#        '2020-04-04', '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08',
#        '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13',
#        '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18',
#        '2020-04-19', '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23',
#        '2020-04-24', '2020-04-25', '2020-04-26'],
#       dtype='object', name='日期')

# %%
#拿到2020年2月-4月数据
alltime_china.loc['2020-02':'2020-04']
# Out:
#              累计确诊   累计疑似   累计治愈  累计死亡   累计重症  当日新增确诊  当日新增疑似  当日新增治愈  当日新增死亡  \
# 日期
# 2020-02-01  14380  19544    328   304   2110    2589    4562      85      45
# 2020-02-02  17205  21558    475   361   2296    2825    5173     147      57
# 2020-02-03  20438  23214    632   425   2788    3233    5072     157      64
# 2020-02-04  24324  23260    892   490   3219    3886    3971     260      65
# 2020-02-05  28018  24702   1153   563   3859    3694    5328     261      73
# 2020-02-06  31161  26359   1540   636   4821    3193    4833     387      73
# 2020-02-07  34546  27657   2050   722   6101    3437    4214     510      86
# 2020-02-08  37198  28942   2649   811   6188    2652    3916     599      89
# 2020-02-09  40171  23589   3281   908   6484    2973    4008     632      97
# 2020-02-10  42638  21675   3996  1016   7333    2467    3536     715     108
# 2020-02-11  44653  16067   4740  1113   8204    2015    3342     644      97
# 2020-02-12  58761  13435   5642  1259   8030   14108    2807    1002     146
# 2020-02-13  63851  10109   6723  1380  10204    5090    2450    1081     121
# 2020-02-14  66492   8969   8096  1523  11053    2641    2277    1373     143
# 2020-02-15  68500   8228   9419  1665  11272    2008    1918    1323     142
# 2020-02-16  70548   7264  10844  1770  10644    2048    1563    1425     105
# 2020-02-17  72436   6242  12552  1868  11741    1888    1432    1708      98
# 2020-02-18  74185   5248  14376  2004  11977    1749    1185    1824     136
# 2020-02-19  75002   4922  16157  2118  11864     817    1277    1781     114
# 2020-02-20  75891   5206  18266  2236  11633     889    1614    2109     118
# 2020-02-21  76288   5365  20659  2345  11477     397    1361    2393     109
# 2020-02-22  76741   4148  22888  2442  10968     453     882    2229      97
# 2020-02-23  77150   3434  24734  2592   9915     409     620    1846     150
# 2020-02-24  77658   2824  27323  2663   9126     508     530    2589      71
# 2020-02-25  78064   2491  29745  2715   8752     406     439    2422      52
# 2020-02-26  78497   2358  32495  2744   8346     433     508    2750      29
# 2020-02-27  78824   2308  36117  2788   7952     327     452    3622      44
# 2020-02-28  79251   1418  39002  2835   7664     427     248    2885      47
# 2020-02-29  79824    851  41625  2870   7365     573     132    2623      35
# 2020-03-01  80026    715  44462  2912   7110     202     141    2837      42
# 2020-03-02  80151    587  47204  2943   6806     125     129    2742      31
# 2020-03-03  80270    520  49856  2981   6416     119     143    2652      38
# 2020-03-04  80409    522  52045  3012   5952     139     143    2189      31
# 2020-03-05  80552    482  53726  3042   5737     143     102    1681      30
# 2020-03-06  80651    502  55404  3070   5489      99      99    1678      28
# 2020-03-07  80695    458  57065  3097   5264      44      84    1661      27
# 2020-03-08  80735    421  58600  3119   5111      40      60    1535      22
# 2020-03-09  80754    349  59897  3136   4794      19      36    1297      17
# 2020-03-10  80778    285  61475  3158   4492      24      31    1578      22
# 2020-03-11  80793    253  62793  3169   4257      15      33    1318      11
# 2020-03-12  80813    147  64111  3176   4020      20      33    1318       7
# 2020-03-13  80824    115  65541  3189   3610      11      17    1430      13
# 2020-03-14  80844    113  66911  3199   3226      20      39    1370      10
# 2020-03-15  80860    134  67749  3213   3032      16      41     838      14
# 2020-03-16  80881    128  68679  3226   2830      21      45     930      13
# 2020-03-17  80894    119  69601  3237   2622      13      21     922      11
# 2020-03-18  80928    105  70420  3245   2314      34      23     819       8
# 2020-03-19  80967    104  71150  3248   2136      39      31     730       3
# 2020-03-20  81008    106  71740  3255   1963      41      36     590       7
# 2020-03-21  81054    118  72244  3261   1845      46      45     504       6
# 2020-03-22  81093    136  72703  3270   1749      39      47     459       9
# 2020-03-23  81171    132  73159  3277   1573      78      35     456       7
# 2020-03-24  81218    134  73650  3281   1399      47      33     491       4
# 2020-03-25  81285    159  74051  3287   1235      67      58     401       6
# 2020-03-26  81340    189  74588  3292   1034      55      49     537       5
# 2020-03-27  81394    184  74971  3295    921      54      29     383       3
# 2020-03-28  81439    174  75448  3300    742      45      28     477       5
# 2020-03-29  81470    168  75770  3304    633      31      17     322       4
# 2020-03-30  81518    183  76052  3305    528      48      44     282       1
# 2020-03-31  81554    172  76238  3312    466      36      26     186       7
#
#             当日新增疑似  当日现存确诊
# 日期
# 2020-02-01       0   13748
# 2020-02-02       0   16369
# 2020-02-03       0   19381
# 2020-02-04       0   22942
# 2020-02-05       0   26302
# 2020-02-06       0   28985
# 2020-02-07       0   31774
# 2020-02-08       0   33738
# 2020-02-09       0   35982
# 2020-02-10       0   37626
# 2020-02-11       0   38800
# 2020-02-12       0   51860
# 2020-02-13       0   55748
# 2020-02-14       0   56873
# 2020-02-15       0   57416
# 2020-02-16       0   57934
# 2020-02-17       0   58016
# 2020-02-18       0   57805
# 2020-02-19       0   56727
# 2020-02-20       0   55389
# 2020-02-21       0   53284
# 2020-02-22       0   51411
# 2020-02-23       0   49824
# 2020-02-24       0   47672
# 2020-02-25       0   45604
# 2020-02-26       0   43258
# 2020-02-27       0   39919
# 2020-02-28       0   37414
# 2020-02-29       0   35329
# 2020-03-01       0   32652
# 2020-03-02       0   30004
# 2020-03-03       0   27433
# 2020-03-04       0   25352
# 2020-03-05       0   23784
# 2020-03-06       0   22177
# 2020-03-07       0   20533
# 2020-03-08       0   19016
# 2020-03-09       0   17721
# 2020-03-10       0   16145
# 2020-03-11       0   14831
# 2020-03-12       0   13526
# 2020-03-13       0   12094
# 2020-03-14       0   10734
# 2020-03-15       0    9898
# 2020-03-16       0    8976
# 2020-03-17       0    8056
# 2020-03-18       0    7263
# 2020-03-19       0    6569
# 2020-03-20       0    6013
# 2020-03-21       0    5549
# 2020-03-22       0    5120
# 2020-03-23       0    4735
# 2020-03-24       0    4287
# 2020-03-25       0    3947
# 2020-03-26       0    3460
# 2020-03-27       0    3128
# 2020-03-28       0    2691
# 2020-03-29       0    2396
# 2020-03-30       0    2161
# 2020-03-31       0    2004

# %% [markdown]
# ### 绘制疫情数据变化趋势情况

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import datetime
plt.rcParams['font.sans-serif'] = 'SimHei'

# %%
fig,ax = plt.subplots(figsize=(16,9),dpi=200)

alltime_china.plot(marker='o',markersize=1,linewidth=5,ax=ax,use_index=True)

ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%m-%d'))

plt.ylabel('人数')
plt.title('全国新冠肺炎数据折线图',fontsize=15)
plt.grid(axis='y')
plt.savefig('全国新冠肺炎数据折线图.png',dpi=500)
#plt.show()

# %%
#全国新增病例折线图
fig,ax=plt.subplots(figsize=(16,9),dpi=300)
alltime_china['当日新增确诊'].plot(linestyle='--',ax=ax,color='grey')

ax.xaxis.set_major_locator(dates.DayLocator(interval=5))
ax.xaxis.set_major_formatter(dates.DateFormatter('%m-%d'))

plt.title('全国新增确诊折线图',fontsize=20,color='k')
plt.xlabel('日期',fontsize=20,color='k')
plt.ylabel('人数',fontsize=20,color='k')
plt.grid(b=True)
plt.savefig('全国新增确诊折线图.png',dpi=500)
plt.show()

# %% [markdown]
# ### https://matplotlib.org/gallery/lines_bars_and_markers/linestyles.html#sphx-glr-gallery-lines-bars-and-markers-linestyles-py
